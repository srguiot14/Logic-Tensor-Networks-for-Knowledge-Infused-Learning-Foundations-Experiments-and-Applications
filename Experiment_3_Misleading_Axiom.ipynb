# %% [markdown]
# # EXPERIMENT 3 NOTEBOOK: MISLEADING AXIOM

# %% [markdown]
# ### Installing LTN (provided in .yml , but just in case)

# %%
pip install ltn
# Out:
# Collecting ltn
#   Downloading ltn-2.1-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from ltn) (2.0.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (from ltn) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (26.1)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (1.80.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->ltn) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow->ltn) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow->ltn) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow->ltn) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow->ltn) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->ltn) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->ltn) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->ltn) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->ltn) (2026.4.22)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow->ltn) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow->ltn) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow->ltn) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow->ltn) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow->ltn) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow->ltn) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow->ltn) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow->ltn) (0.1.2)
# Downloading ltn-2.1-py3-none-any.whl (13 kB)
# Installing collected packages: ltn
# Successfully installed ltn-2.1

# %% [markdown]
# ### Imports and notebook parameters

# %%
import logging
logging.basicConfig(level=logging.INFO)

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1.1)

import ltn

# Training parameters to modify at user's will
BATCH_SIZE = 128
LR = 5e-4
EPOCHS = 1500

# Amount of neighbours previous and posterior considered on the monotonicity axiom. Can be adjusted. It obey computational cost reasons.
K_NEIGHBORS = 3      

# Parameter to regulate the weight that monotonicity axiom has (1-lambda is the weight of the regression axiom)
LAMBDA_LOGIC = 0.05    

CSV_PATH = "data/height_weight_train.csv"

# %% [markdown]
# ### Data Loading

# %%
# Data loading
# df = pd.read_csv('height_weight_train.csv')
df = pd.read_csv(CSV_PATH)
df = df.sample(frac=1)  # shuffle

# Feature and target
x = df[['height_m']].astype(np.float32)
y = df[['weight']].astype(np.float32)

split = int(0.8 * len(df))
x_train, y_train = x[:split], y[:split]
x_test,  y_test  = x[split:], y[split:]

# Datasets
ds_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(BATCH_SIZE)
ds_test  = tf.data.Dataset.from_tensor_slices((x_test,  y_test)).batch(BATCH_SIZE)

print("Train:", x_train.shape, y_train.shape)
print("Test:",  x_test.shape,  y_test.shape)
# Out:
# Train: (240, 1) (240, 1)
# Test: (60, 1) (60, 1)

# %% [markdown]
# ## Knowledge Base

# %% [markdown]
# #### Model and axioms predicates

# %%
# LTN MLP model with 1D entry
model_f = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)),
    tf.keras.layers.Dense(8, activation="elu"),
    tf.keras.layers.Dense(8, activation="elu"),
    tf.keras.layers.Dense(1)   # sortida escalar
])

# LTN Function that wraps the model
f = ltn.Function(model_f)

# Regression predicate with robust equalty (exp)
eq = ltn.Predicate.Lambda(
    lambda args: tf.exp(-0.01 * tf.abs(args[0] - args[1]))
)

# Soft sigmoid predicates for monotonicity axiom.
g = ltn.Predicate.Lambda(lambda args: tf.sigmoid(20.0 * (args[0] - args[1])))  # x1 >= x2
h = ltn.Predicate.Lambda(lambda args: tf.sigmoid(20.0 * (args[1] - args[0])))  # f(x1) =< f(x2)

# %% [markdown]
# ### Logical operators

# %% [markdown]
# We use the classical Product real Logic configuration. We defined 2 different ForAll operators, a soft one for monotonicity axiom and a strict one for regression axiom.

# %%
# Strict Forall for regression axiom (p=2, pMeanError)
Forall_reg = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMeanError(p=4), semantics="forall")

# Soft Forall for monotonicity axiom(p=1, pMean)
Forall_mon = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(p=1), semantics="forall")

Not = ltn.Wrapper_Connective(ltn.fuzzy_ops.Not_Std())
And = ltn.Wrapper_Connective(ltn.fuzzy_ops.And_Prod())
Or = ltn.Wrapper_Connective(ltn.fuzzy_ops.Or_ProbSum())
Exists = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(p=2), semantics="exists")
Implies = ltn.Wrapper_Connective(ltn.fuzzy_ops.Implies_Reichenbach())

# %% [markdown]
# #### Regression axiom

# %%
def regression_axiom(x_data, y_data):
    x_var = ltn.Variable("x", x_data)
    y_var = ltn.Variable("y", y_data)
    return Forall_reg(ltn.diag(x_var, y_var), eq([f(x_var), y_var])).tensor

# %% [markdown]
# #### Monotonicity axiom

# %% [markdown]
# Neighbour defining function for computing the monotonicity near a point.

# %%
def neighbor_pairs_from_batch(x_batch, k=3):

    # Ensure its a numpy array
    if isinstance(x_batch, tf.Tensor):
        x_np = x_batch.numpy()
    else:
        x_np = np.asarray(x_batch)

    N = x_np.shape[0]
    if N <= 1:
        return tf.constant([], shape=(0,1), dtype=tf.float32), tf.constant([], shape=(0,1), dtype=tf.float32)

    # Order by the value of x
    order = np.argsort(x_np[:,0])
    pairs_idx = []
    for pos in range(N):
        i = order[pos]
        # previous neighbours
        for offset in range(1, k+1):
            jpos = pos - offset
            if jpos < 0:
                break
            j = order[jpos]
            pairs_idx.append((i, j))
        # posterior neighbours
        for offset in range(1, k+1):
            jpos = pos + offset
            if jpos >= N:
                break
            j = order[jpos]
            pairs_idx.append((i, j))

    if len(pairs_idx) == 0:
        return tf.constant([], shape=(0,1), dtype=tf.float32), tf.constant([], shape=(0,1), dtype=tf.float32)

    idxs = np.array(pairs_idx, dtype=np.int32)
    x1 = x_np[idxs[:,0], :].astype(np.float32)
    x2 = x_np[idxs[:,1], :].astype(np.float32)

    return tf.convert_to_tensor(x1), tf.convert_to_tensor(x2)

# %% [markdown]
# Monotonicity axiom itself.

# %%
def monotonicity_axiom_neighbors(x_batch, k=K_NEIGHBORS):
    x1_t, x2_t = neighbor_pairs_from_batch(x_batch, k=k)
    if tf.shape(x1_t)[0] == 0:
        return tf.constant(1.0, dtype=tf.float32)  

    x1_term = ltn.Variable("x1", x1_t)
    x2_term = ltn.Variable("x2", x2_t)

    f1 = f(x1_term)
    f2 = f(x2_term)

    g_formula = g([x1_term, x2_term])
    h_formula = h([f1, f2])
    impl_formula = Implies(g_formula, h_formula)

    sat = Forall_mon((x1_term, x2_term), impl_formula).tensor
    return sat

# %% [markdown]
# #### Groundings inspecting function.

# %%
def inspect_ltn(obj, name="obj", max_values=10):
    print(f"\n=== {name} ===")
    print("Python type:", type(obj))
    # Want to check if it's LTN object with .tensor
    t = None
    if hasattr(obj, "tensor"):
        t = obj.tensor
        print("LTN object with .tensor")
    else:
        t = obj

    if isinstance(t, tf.Tensor):
        arr = t.numpy()
        print("Shape:", arr.shape)
        print("Rank:", arr.ndim)
        print("Dtype:", arr.dtype)
        flat = arr.flatten()
        n = flat.size
        if n == 0:
            print("Empty tensor")
        else:
            print("First values:", flat[:max_values], "..." if n > max_values else "")
    else:
        print("Value:", t)

# %% [markdown]
# ## Training

# %%
# Optimizer and metrics
optimizer = tf.keras.optimizers.Adam(learning_rate=LR)

train_sat_metric = tf.keras.metrics.Mean(name='train_sat')
train_mon_sat_metric = tf.keras.metrics.Mean(name='train_mon_sat')
test_sat_metric  = tf.keras.metrics.Mean(name='test_sat')
test_mon_sat_metric = tf.keras.metrics.Mean(name='test_mon_sat')
train_rmse = tf.keras.metrics.RootMeanSquaredError(name='train_rmse')
test_rmse  = tf.keras.metrics.RootMeanSquaredError(name='test_rmse')

# HISTORY FOR EPOCH (NO FOR BATCH)
epoch_mon_train = []
epoch_mon_test = []
epoch_reg_train = []
epoch_reg_test = []

# ManualTraining loop (eager)
for epoch in range(1, EPOCHS+1):

    # Reset metrics for epoch
    train_sat_metric.reset_state()
    train_rmse.reset_state()
    train_mon_sat_metric.reset_state()

    # ---------- TRAIN ----------
    for x_b, y_b in ds_train:
        with tf.GradientTape() as tape:
            sat_reg = regression_axiom(x_b, y_b)
            sat_mon = monotonicity_axiom_neighbors(x_b, k=K_NEIGHBORS)

            loss_reg = 1.0 - sat_reg
            loss_mon = 1.0 - sat_mon
            loss = (1.0 - LAMBDA_LOGIC) * loss_reg + LAMBDA_LOGIC * loss_mon

        grads = tape.gradient(loss, f.trainable_variables)
        optimizer.apply_gradients(zip(grads, f.trainable_variables))

        # Update metrics
        train_sat_metric.update_state(sat_reg)
        preds = f.model(x_b)
        train_rmse.update_state(y_b, preds)
        train_mon_sat_metric.update_state(sat_mon)

    # Save Satisfaction for epoch
    epoch_reg_train.append(float(train_sat_metric.result().numpy()))
    epoch_mon_train.append(float(train_mon_sat_metric.result().numpy()))

    # ---------- TEST ----------
    test_sat_metric.reset_state()
    test_rmse.reset_state()
    test_mon_sat_metric.reset_state()

    for x_b, y_b in ds_test:
        sat_reg = regression_axiom(x_b, y_b)
        sat_mon = monotonicity_axiom_neighbors(x_b, k=K_NEIGHBORS)

        test_sat_metric.update_state(sat_reg)
        preds = f.model(x_b)
        test_rmse.update_state(y_b, preds)
        test_mon_sat_metric.update_state(sat_mon)

    # Safe satisfaction for epoch
    epoch_reg_test.append(float(test_sat_metric.result().numpy()))
    epoch_mon_test.append(float(test_mon_sat_metric.result().numpy()))

    # ---------- PRINT ----------
    if epoch % 50 == 0 or epoch == 1:
        print(f"Epoch {epoch:04d} | "
              f"train_sat={train_sat_metric.result().numpy():.4f} | "
              f"test_sat={test_sat_metric.result().numpy():.4f} | "
              f"train_rmse={train_rmse.result().numpy():.4f} | "
              f"test_rmse={test_rmse.result().numpy():.4f}")
        print(f"Epoch {epoch:04d} | "
              f"train_mon_sat={train_mon_sat_metric.result().numpy():.4f} | "
              f"test_mon_sat={test_mon_sat_metric.result().numpy():.4f}")
# Out:
# Epoch 0001 | train_sat=0.2284 | test_sat=0.2324 | train_rmse=148.9069 | test_rmse=147.0419
# Epoch 0001 | train_mon_sat=0.7081 | test_mon_sat=0.7102
# Epoch 0050 | train_sat=0.2276 | test_sat=0.2317 | train_rmse=149.2682 | test_rmse=147.3960
# Epoch 0050 | train_mon_sat=0.8641 | test_mon_sat=0.8670
# Epoch 0100 | train_sat=0.2279 | test_sat=0.2320 | train_rmse=149.1409 | test_rmse=147.2646
# Epoch 0100 | train_mon_sat=0.8945 | test_mon_sat=0.8967
# Epoch 0150 | train_sat=0.2287 | test_sat=0.2328 | train_rmse=148.8033 | test_rmse=146.9249
# Epoch 0150 | train_mon_sat=0.9042 | test_mon_sat=0.9062
# Epoch 0200 | train_sat=0.2301 | test_sat=0.2342 | train_rmse=148.1729 | test_rmse=146.2922
# Epoch 0200 | train_mon_sat=0.9076 | test_mon_sat=0.9095
# Epoch 0250 | train_sat=0.2325 | test_sat=0.2367 | train_rmse=147.1275 | test_rmse=145.2443
# Epoch 0250 | train_mon_sat=0.9083 | test_mon_sat=0.9102
# Epoch 0300 | train_sat=0.2362 | test_sat=0.2405 | train_rmse=145.5210 | test_rmse=143.6353
# Epoch 0300 | train_mon_sat=0.9081 | test_mon_sat=0.9099
# Epoch 0350 | train_sat=0.2417 | test_sat=0.2461 | train_rmse=143.1812 | test_rmse=141.2915
# Epoch 0350 | train_mon_sat=0.9085 | test_mon_sat=0.9100
# Epoch 0400 | train_sat=0.2496 | test_sat=0.2542 | train_rmse=139.9222 | test_rmse=138.0292
# Epoch 0400 | train_mon_sat=0.9088 | test_mon_sat=0.9098
# Epoch 0450 | train_sat=0.2604 | test_sat=0.2651 | train_rmse=135.6564 | test_rmse=133.7587
# Epoch 0450 | train_mon_sat=0.9086 | test_mon_sat=0.9091
# Epoch 0500 | train_sat=0.2751 | test_sat=0.2802 | train_rmse=130.0576 | test_rmse=128.1548
# Epoch 0500 | train_mon_sat=0.9073 | test_mon_sat=0.9071
# Epoch 0550 | train_sat=0.2952 | test_sat=0.3007 | train_rmse=122.8805 | test_rmse=120.9725
# Epoch 0550 | train_mon_sat=0.9054 | test_mon_sat=0.9044
# Epoch 0600 | train_sat=0.3228 | test_sat=0.3289 | train_rmse=113.7637 | test_rmse=111.8498
# Epoch 0600 | train_mon_sat=0.9023 | test_mon_sat=0.9000
# Epoch 0650 | train_sat=0.3609 | test_sat=0.3676 | train_rmse=102.3687 | test_rmse=100.4509
# Epoch 0650 | train_mon_sat=0.8971 | test_mon_sat=0.8935
# Epoch 0700 | train_sat=0.4135 | test_sat=0.4212 | train_rmse=88.3459 | test_rmse=86.4283
# Epoch 0700 | train_mon_sat=0.8898 | test_mon_sat=0.8840
# Epoch 0750 | train_sat=0.4867 | test_sat=0.4954 | train_rmse=71.3550 | test_rmse=69.4500
# Epoch 0750 | train_mon_sat=0.8782 | test_mon_sat=0.8698
# Epoch 0800 | train_sat=0.5861 | test_sat=0.5953 | train_rmse=51.5491 | test_rmse=49.7032
# Epoch 0800 | train_mon_sat=0.8552 | test_mon_sat=0.8426
# Epoch 0850 | train_sat=0.7505 | test_sat=0.7595 | train_rmse=24.6638 | test_rmse=23.1645
# Epoch 0850 | train_mon_sat=0.5568 | test_mon_sat=0.5548
# Epoch 0900 | train_sat=0.8635 | test_sat=0.8576 | train_rmse=13.0485 | test_rmse=13.3676
# Epoch 0900 | train_mon_sat=0.5546 | test_mon_sat=0.5536
# Epoch 0950 | train_sat=0.8663 | test_sat=0.8604 | train_rmse=12.7441 | test_rmse=13.0580
# Epoch 0950 | train_mon_sat=0.5546 | test_mon_sat=0.5536
# Epoch 1000 | train_sat=0.8687 | test_sat=0.8628 | train_rmse=12.4966 | test_rmse=12.8022
# Epoch 1000 | train_mon_sat=0.5546 | test_mon_sat=0.5536
# Epoch 1050 | train_sat=0.8707 | test_sat=0.8649 | train_rmse=12.2808 | test_rmse=12.5802
# Epoch 1050 | train_mon_sat=0.5546 | test_mon_sat=0.5536
# Epoch 1100 | train_sat=0.8725 | test_sat=0.8667 | train_rmse=12.0855 | test_rmse=12.3798
# Epoch 1100 | train_mon_sat=0.5546 | test_mon_sat=0.5536
# Epoch 1150 | train_sat=0.8743 | test_sat=0.8684 | train_rmse=11.9042 | test_rmse=12.1945
# Epoch 1150 | train_mon_sat=0.5545 | test_mon_sat=0.5536
# Epoch 1200 | train_sat=0.8759 | test_sat=0.8701 | train_rmse=11.7331 | test_rmse=12.0198
# Epoch 1200 | train_mon_sat=0.5545 | test_mon_sat=0.5535
# Epoch 1250 | train_sat=0.8775 | test_sat=0.8716 | train_rmse=11.5692 | test_rmse=11.8529
# Epoch 1250 | train_mon_sat=0.5545 | test_mon_sat=0.5535
# Epoch 1300 | train_sat=0.8790 | test_sat=0.8732 | train_rmse=11.4106 | test_rmse=11.6916
# Epoch 1300 | train_mon_sat=0.5545 | test_mon_sat=0.5535
# Epoch 1350 | train_sat=0.8804 | test_sat=0.8746 | train_rmse=11.2557 | test_rmse=11.5342
# Epoch 1350 | train_mon_sat=0.5545 | test_mon_sat=0.5535
# Epoch 1400 | train_sat=0.8819 | test_sat=0.8761 | train_rmse=11.1031 | test_rmse=11.3795
# Epoch 1400 | train_mon_sat=0.5545 | test_mon_sat=0.5535
# Epoch 1450 | train_sat=0.8834 | test_sat=0.8775 | train_rmse=10.9518 | test_rmse=11.2263
# Epoch 1450 | train_mon_sat=0.5545 | test_mon_sat=0.5535
# Epoch 1500 | train_sat=0.8848 | test_sat=0.8790 | train_rmse=10.8009 | test_rmse=11.0736
# Epoch 1500 | train_mon_sat=0.5545 | test_mon_sat=0.5535

# %%
# Inspect a small batch
for x_b, y_b in ds_train.take(1):
    print("Batch shapes:", x_b.shape, y_b.shape)
    # inspect terms
    x1, x2 = neighbor_pairs_from_batch(x_b, k=2)
    inspect_ltn(x_b, "x_batch")
    inspect_ltn(x1, "x1 (pairs)")
    inspect_ltn(x2, "x2 (pairs)")
    # inspect f among a few
    x_var = ltn.Variable("x", x_b[:8])
    fx = f(x_var)
    inspect_ltn(fx, "f(x) for first 8")
    break
# Out:
# Batch shapes: (128, 1) (128, 1)
#
# === x_batch ===
# Python type: <class 'tensorflow.python.framework.ops.EagerTensor'>
# Shape: (128, 1)
# Rank: 2
# Dtype: float32
# First values: [1.9799929 1.4470738 1.6391028 1.9642751 1.7009097 1.7818463 1.6027972
#  1.9264238 1.764527  1.9913902] ...
#
# === x1 (pairs) ===
# Python type: <class 'tensorflow.python.framework.ops.EagerTensor'>
# Shape: (506, 1)
# Rank: 2
# Dtype: float32
# First values: [1.409274  1.409274  1.4099526 1.4099526 1.4099526 1.4145895 1.4145895
#  1.4145895 1.4145895 1.4159068] ...
#
# === x2 (pairs) ===
# Python type: <class 'tensorflow.python.framework.ops.EagerTensor'>
# Shape: (506, 1)
# Rank: 2
# Dtype: float32
# First values: [1.4099526 1.4145895 1.409274  1.4145895 1.4159068 1.4099526 1.409274
#  1.4159068 1.4215654 1.4145895] ...
#
# === f(x) for first 8 ===
# Python type: <class 'ltn.core.Term'>
# LTN object with .tensor
# Shape: (8, 1)
# Rank: 2
# Dtype: float32
# First values: [158.9241  140.03764 146.97556 158.38272 149.17535 152.03296 145.67606
#  157.07529]

# %% [markdown]
# ## Predictions and results

# %%
# Collect predictions
def collect_preds(dataset):
    y_pred = []
    y_true = []
    for x_b, y_b in dataset:
        preds = f.model(x_b).numpy().reshape(-1)
        trues = y_b.numpy().reshape(-1)
        y_pred.extend(preds)
        y_true.extend(trues)
    return np.array(y_true), np.array(y_pred)

y_t_train, y_p_train = collect_preds(ds_train)
y_t_test,  y_p_test  = collect_preds(ds_test)

fig, axs = plt.subplots(1,2,figsize=(12,5))
ax = axs[0]
ax.scatter(y_t_train, y_p_train, alpha=0.5)
m, b = np.polyfit(y_t_train, y_p_train, 1)
ax.plot(np.unique(y_t_train), m*np.unique(y_t_train)+b, color='r', linestyle='--', alpha=0.6)
ax.plot([min(y_t_train), max(y_t_train)], [min(y_t_train), max(y_t_train)], color='gray', linestyle='--')
ax.set_title("Training Data")
ax.set_xlabel("Actual weight")
ax.set_ylabel("Predicted weight")

ax = axs[1]
ax.scatter(y_t_test, y_p_test, alpha=0.5)
m, b = np.polyfit(y_t_test, y_p_test, 1)
ax.plot(np.unique(y_t_test), m*np.unique(y_t_test)+b, color='r', linestyle='--', alpha=0.6)
ax.plot([min(y_t_test), max(y_t_test)], [min(y_t_test), max(y_t_test)], color='gray', linestyle='--')
ax.set_title("Test Data")
ax.set_xlabel("Actual weight")
ax.set_ylabel("Predicted weight")

plt.tight_layout()
plt.show()

# %%
def plot_height_vs_weight(x, y_true, y_pred, title):
    plt.figure(figsize=(10,5))
    plt.scatter(x, y_true, label="Real Data", alpha=0.5)
    plt.scatter(x, y_pred, label="Model Predictions", alpha=0.5)

    plt.xlabel("Height (m)")
    plt.ylabel("Weight (lb)")
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# TRAIN
x_train_np = x_train.values if hasattr(x_train, "values") else x_train
y_pred_train = f.model(x_train_np).numpy().flatten()
plot_height_vs_weight(
    x_train_np.flatten(),
    y_t_train,
    y_pred_train,
    "Model Predictions over TRAIN Data"
)

# TEST
x_test_np = x_test.values if hasattr(x_test, "values") else x_test
y_pred_test = f.model(x_test_np).numpy().flatten()
plot_height_vs_weight(
    x_test_np.flatten(),
    y_t_test,
    y_pred_test,
    "Model Predictions over TEST Data"
)

# %%
plt.figure(figsize=(12,6))
plt.plot(monotonicity_train_history, label="Monotonicity train satisfaction")
plt.plot(monotonicity_test_history, label="Monotonicity test satisfaction")
plt.plot(regression_train_history, label="Regression train satisfaction")
plt.plot(regression_test_history, label="Regression test satisfaction")
plt.xlabel("Training step")
plt.ylabel("Satisfaction")
plt.title("Monotony and regression axiom satisfaction evolution")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Queries

# %% [markdown]
# #### Predicates required for both queries

# %%
# Predicate height < c
def less_than_height(c):
    return ltn.Predicate.Lambda(lambda args: tf.sigmoid(20.0 * (c - args[0])))

# Predicate height > c
def greater_than_height(c):
    return ltn.Predicate.Lambda(lambda args: tf.sigmoid(20.0 * (args[0] - c)))

# Predicate weight < c
def less_than_weight(c):
    return ltn.Predicate.Lambda(lambda args: tf.sigmoid(20.0 * (c - args[0])))

# Predicate weight > c
def greater_than_weight(c):
    return ltn.Predicate.Lambda(lambda args: tf.sigmoid(20.0 * (args[0] - c)))

# %% [markdown]
# #### Query A: Any person shorter than 1.75 m, weights less than 70 lbs.

# %%
# Query A: height < 1.75  =>  weight < 70
H_lt_175 = less_than_height(1.75)
W_lt_70  = less_than_weight(70.0)

def query_A(x_batch, y_batch):
    x_var = ltn.Variable("x", x_batch)
    y_var = ltn.Variable("y", y_batch)

    premise = H_lt_175([x_var])
    conclusion = W_lt_70([y_var])
    implication = Implies(premise, conclusion)

    return Forall_mon((x_var, y_var), implication).tensor

# %% [markdown]
# #### Query B: Any person taller than 1.65 m, weights more than 75 lbs.

# %%
# Query B: height > 1.65  =>  weight > 75
H_gt_165 = greater_than_height(1.65)
W_gt_75  = greater_than_weight(75.0)

def query_B(x_batch, y_batch):
    x_var = ltn.Variable("x", x_batch)
    y_var = ltn.Variable("y", y_batch)

    premise = H_gt_165([x_var])
    conclusion = W_gt_75([y_var])
    implication = Implies(premise, conclusion)

    return Forall_mon((x_var, y_var), implication).tensor

# %%
for x_b, y_b in ds_test.take(1):
    qA = query_A(x_b, y_b).numpy()
    qB = query_B(x_b, y_b).numpy()

print("Query A (height < 1.75 => weight < 70):", qA)
print("Query B (height > 1.65 => weight > 75):", qB)
# Out:
# Consulta A (height < 1.75 => weight < 70): 0.3725407
# Consulta B (height > 1.65 => weight > 75): 0.9999482

# %% [markdown]
# ### Out Of Distribution (OOD) data

# %%
# Load OOD data
df_ood = pd.read_csv("data/height_weight_extrapolation.csv")

x_ood = df_ood[["height_m"]].astype(np.float32).values
y_ood = df_ood[["weight"]].astype(np.float32).values

ds_ood = tf.data.Dataset.from_tensor_slices((x_ood, y_ood)).batch(128)

print("OOD Sample loaded:", x_ood.shape, y_ood.shape)
df_ood.head()
# Out:
# Mostra OOD carregada: (400, 1) (400, 1)
#    height_m     weight
# 0   1.00000  91.115400
# 1   1.00201  91.018210
# 2   1.00402  92.947840
# 3   1.00603  91.257070
# 4   1.00804  88.914444

# %% [markdown]
# DataSet evaluation function. It returns the RMSE, the satisfaction degree of the regression axiom and of the monotonicity axiom.

# %%
def evaluate_dataset(dataset):

    rmse_metric = tf.keras.metrics.RootMeanSquaredError()
    sat_reg_metric = tf.keras.metrics.Mean()
    sat_mon_metric = tf.keras.metrics.Mean()

    for x_b, y_b in dataset:
        preds = f.model(x_b)
        rmse_metric.update_state(y_b, preds)

        sat_reg = regression_axiom(x_b, y_b)
        sat_mon = monotonicity_axiom_neighbors(x_b, k=K_NEIGHBORS)

        sat_reg_metric.update_state(sat_reg)
        sat_mon_metric.update_state(sat_mon)

    return {
        "rmse": float(rmse_metric.result().numpy()),
        "sat_reg": float(sat_reg_metric.result().numpy()),
        "sat_mon": float(sat_mon_metric.result().numpy())
    }

# %% [markdown]
# ### OOD data results

# %%
results_ood = evaluate_dataset(ds_ood)

print("=== OOD Results ===")
print(f"RMSE: {results_ood['rmse']:.4f}")
print(f"Regression satisfaction: {results_ood['sat_reg']:.4f}")
print(f"Monotony Satisfaction: {results_ood['sat_mon']:.4f}")
# Out:
# === Resultats OOD ===
# RMSE: 28.0119
# Satisfacció regressió: 0.7391
# Satisfacció monotonia: 0.6368

# %% [markdown]
# #### Predicted vs Real value comparison

# %%
# Predictions OOD
y_pred_ood = f.model(x_ood).numpy().flatten()

plt.figure(figsize=(10,5))
plt.scatter(x_ood, y_ood, label="Real OOD data", alpha=0.5)
plt.scatter(x_ood, y_pred_ood, label="Model predictions", alpha=0.5)
plt.xlabel("Height (m)")
plt.ylabel("Weight (lb)")
plt.title("Model predictions over OOD data")
plt.legend()
plt.grid(True)
plt.show()

# %%
def plot_pred_vs_actual(y_true, y_pred, title):
    plt.figure(figsize=(6,5))
    plt.scatter(y_true, y_pred, alpha=0.5)

    # Lineal fit
    m, b = np.polyfit(y_true, y_pred, 1)
    xs = np.linspace(min(y_true), max(y_true), 100)
    plt.plot(xs, m*xs + b, color='red', linestyle='--', alpha=0.6, label="Linear fit")

    # Identity line 
    plt.plot(xs, xs, color='gray', linestyle='--', label="Identity")

    plt.xlabel("Actual weight")
    plt.ylabel("Predicted weight")
    plt.title(title)
    plt.grid(True)
    plt.legend()
    plt.show()

# TRAIN
y_t_train, y_p_train = collect_preds(ds_train)
plot_pred_vs_actual(y_t_train, y_p_train, "Training Data")

# TEST
y_t_test, y_p_test = collect_preds(ds_test)
plot_pred_vs_actual(y_t_test, y_p_test, "Test Data")

# OOD (Extrapolation)
y_t_ood, y_p_ood = collect_preds(ds_ood)
plot_pred_vs_actual(y_t_ood, y_p_ood, "OOD (Extrapolation) Data")

# %%
# Prepare TRAIN data
x_train_np = x_train.values if hasattr(x_train, "values") else x_train
y_pred_train = f.model(x_train_np).numpy().flatten()

# Prepare OOD data 
x_ood_np = x_ood
y_pred_ood = f.model(x_ood_np).numpy().flatten()

plt.figure(figsize=(12,6))

# TRAIN: reals and predictions
plt.scatter(x_train_np, y_t_train, label="Train - Real", alpha=0.5, color="blue")
plt.scatter(x_train_np, y_pred_train, label="Train - Prediction", alpha=0.5, color="cyan")

# OOD: reals and predictions
plt.scatter(x_ood_np, y_t_ood, label="OOD - Real", alpha=0.5, color="red")
plt.scatter(x_ood_np, y_pred_ood, label="OOD - Prediction", alpha=0.5, color="orange")

plt.xlabel("Height (m)")
plt.ylabel("Weight (lb)")
plt.title("Model predictions over TRAIN and OOD (Extrapolation)")
plt.grid(True)
plt.legend()
plt.show()
